# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('amazon.csv',encoding='latin')

# %%
data.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %%
data.dtypes
# Out:
# year        int64
# state      object
# month      object
# number    float64
# date       object
# dtype: object

# %%
data=pd.read_csv('amazon.csv',encoding='latin',parse_dates=['date'])

# %%
data.dtypes
# Out:
# year               int64
# state             object
# month             object
# number           float64
# date      datetime64[ns]
# dtype: object

# %%
data.shape
# Out:
# (6454, 5)

# %%
data.head()
# Out:
#    year state    month  number       date
# 0  1998  Acre  Janeiro     0.0 1998-01-01
# 1  1999  Acre  Janeiro     0.0 1999-01-01
# 2  2000  Acre  Janeiro     0.0 2000-01-01
# 3  2001  Acre  Janeiro     0.0 2001-01-01
# 4  2002  Acre  Janeiro     0.0 2002-01-01

# %%
data.tail()
# Out:
#       year      state     month  number       date
# 6449  2012  Tocantins  Dezembro   128.0 2012-01-01
# 6450  2013  Tocantins  Dezembro    85.0 2013-01-01
# 6451  2014  Tocantins  Dezembro   223.0 2014-01-01
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 252.2+ KB

# %%
data.describe()
# Out:
#               year       number
# count  6454.000000  6454.000000
# mean   2007.461729   108.293163
# std       5.746654   190.812242
# min    1998.000000     0.000000
# 25%    2002.000000     3.000000
# 50%    2007.000000    24.000000
# 75%    2012.000000   113.000000
# max    2017.000000   998.000000

# %%
data.describe(include='all')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3704\1336221646.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all')
#                year state    month       number                 date
# count   6454.000000  6454     6454  6454.000000                 6454
# unique          NaN    23       12          NaN                   20
# top             NaN   Rio  Janeiro          NaN  1998-01-01 00:00:00
# freq            NaN   717      541          NaN                  324
# first           NaN   NaN      NaN          NaN  1998-01-01 00:00:00
# last            NaN   NaN      NaN          NaN  2017-01-01 00:00:00
# mean    2007.461729   NaN      NaN   108.293163                  NaN
# std        5.746654   NaN      NaN   190.812242                  NaN
# ...

# %%
data.duplicated().any()    #checking for duplicated values
# Out:
# True

# %%
data[data.duplicated()]
# Out:
#       year        state      month  number       date
# 259   2017      Alagoas    Janeiro    38.0 2017-01-01
# 2630  1998  Mato Grosso    Janeiro     0.0 1998-01-01
# 2650  1998  Mato Grosso  Fevereiro     0.0 1998-01-01
# 2670  1998  Mato Grosso      Março     0.0 1998-01-01
# 2690  1998  Mato Grosso      Abril     0.0 1998-01-01
# 2710  1998  Mato Grosso       Maio     0.0 1998-01-01
# 3586  1998      Paraiba    Janeiro     0.0 1998-01-01
# 3606  1998      Paraiba  Fevereiro     0.0 1998-01-01
# 3621  2013      Paraiba  Fevereiro     9.0 2013-01-01
# 3626  1998      Paraiba      Março     0.0 1998-01-01
# 3646  1998      Paraiba      Abril     0.0 1998-01-01
# 3666  1998      Paraiba       Maio     0.0 1998-01-01
# 4542  1998          Rio    Janeiro     0.0 1998-01-01
# 4562  1998          Rio  Fevereiro     0.0 1998-01-01
# 4582  1998          Rio      Março     0.0 1998-01-01
# 4585  2001          Rio      Março     0.0 2001-01-01
# ...

# %%
len(data[data.duplicated()])
# Out:
# 32

# %%
data.shape
# Out:
# (6454, 5)

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (6422, 5)

# %% [markdown]
# #### checking null values in the dataset

# %%
data.isnull().sum()
# Out:
# year      0
# state     0
# month     0
# number    0
# date      0
# dtype: int64

# %%
data.describe(include='all')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3704\1336221646.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include='all')
#                year state   month       number                 date
# count   6422.000000  6422    6422  6422.000000                 6422
# unique          NaN    23      12          NaN                   20
# top             NaN   Rio  Agosto          NaN  2015-01-01 00:00:00
# freq            NaN   697     540          NaN                  324
# first           NaN   NaN     NaN          NaN  1998-01-01 00:00:00
# last            NaN   NaN     NaN          NaN  2017-01-01 00:00:00
# mean    2007.490969   NaN     NaN   108.815178                  NaN
# std        5.731806   NaN     NaN   191.142482                  NaN
# ...

# %%
data.describe(include='all',datetime_is_numeric=True)
# Out:
#                year state   month       number                           date
# count   6422.000000  6422    6422  6422.000000                           6422
# unique          NaN    23      12          NaN                            NaN
# top             NaN   Rio  Agosto          NaN                            NaN
# freq            NaN   697     540          NaN                            NaN
# mean    2007.490969   NaN     NaN   108.815178  2007-06-29 10:46:40.622859008
# min     1998.000000   NaN     NaN     0.000000            1998-01-01 00:00:00
# 25%     2003.000000   NaN     NaN     3.000000            2003-01-01 00:00:00
# 50%     2007.000000   NaN     NaN    24.497000            2007-01-01 00:00:00
# 75%     2012.000000   NaN     NaN   114.000000            2012-01-01 00:00:00
# max     2017.000000   NaN     NaN   998.000000            2017-01-01 00:00:00
# std        5.731806   NaN     NaN   191.142482                            NaN

# %% [markdown]
# ### Rename month names to english

# %%
data['month']
# Out:
# 0        Janeiro
# 1        Janeiro
# 2        Janeiro
# 3        Janeiro
# 4        Janeiro
#           ...
# 6449    Dezembro
# 6450    Dezembro
# 6451    Dezembro
# 6452    Dezembro
# 6453    Dezembro
# Name: month, Length: 6422, dtype: object

# %%
data['month'].unique()
# Out:
# array(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho',
#        'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'],
#       dtype=object)

# %%
data['month_new']=data['month'].map({'Janeiro':'jan', 'Fevereiro':'feb', 'Março':'mar', 'Abril':'apr', 'Maio':'may', 'Junho':'jun', 'Julho':'jul',
       'Agosto':'aug', 'Setembro':'sep', 'Outubro':'oct', 'Novembro':'nov', 'Dezembro':'dec'})

# %%
data.head()
# Out:
#    year state    month  number       date month_new
# 0  1998  Acre  Janeiro     0.0 1998-01-01       jan
# 1  1999  Acre  Janeiro     0.0 1999-01-01       jan
# 2  2000  Acre  Janeiro     0.0 2000-01-01       jan
# 3  2001  Acre  Janeiro     0.0 2001-01-01       jan
# 4  2002  Acre  Janeiro     0.0 2002-01-01       jan

# %% [markdown]
# ### Total number of fires registered

# %%
data.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'month_new'], dtype='object')

# %%
data.shape
# Out:
# (6422, 6)

# %% [markdown]
# ### name the maximum fires reported month

# %%
data['number'].max()
# Out:
# 998.0

# %%
data[data['number']==data['number'].max()]
# Out:
#      year     state     month  number       date month_new
# 888  2008  Amazonas  Setembro   998.0 2008-01-01       sep

# %%
data[data['number']==data['number'].max()]['month_new']
# Out:
# 888    sep
# Name: month_new, dtype: object

# %%
data.nlargest(1,'number')[['month_new','number']]
# Out:
#     month_new  number
# 888       sep   998.0

# %% [markdown]
# ### In which Month Maximum number of forest fires were reported?

# %%
data.groupby('month_new')['number']

# %%
data.groupby('month_new')['number'].sum()
# Out:
# month_new
# apr    28184.770
# aug    88050.435
# dec    57535.480
# feb    30839.050
# jan    47681.844
# jul    92319.113
# jun    55997.675
# mar    30709.405
# may    34725.363
# nov    85508.054
# oct    88681.579
# sep    58578.305
# Name: number, dtype: float64

# %%
data.groupby('month_new')['number'].sum().sort_values(ascending=False)
# Out:
# month_new
# jul    92319.113
# oct    88681.579
# aug    88050.435
# nov    85508.054
# sep    58578.305
# dec    57535.480
# jun    55997.675
# jan    47681.844
# may    34725.363
# feb    30839.050
# mar    30709.405
# apr    28184.770
# Name: number, dtype: float64

# %%
data1=data.groupby('month_new')['number'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='month_new',y='number',data=data1)
# Out:
# <Axes: xlabel='month_new', ylabel='number'>

# %% [markdown]
# ### In which year Maximum number of forest fires were reported?

# %%
data.groupby('year')['number'].sum()
# Out:
# year
# 1998    20013.971
# 1999    26882.821
# 2000    27351.251
# 2001    29054.612
# 2002    37390.600
# 2003    42760.674
# 2004    38450.163
# 2005    35004.965
# 2006    33824.161
# 2007    33028.413
# 2008    29378.964
# 2009    39116.178
# 2010    37037.449
# 2011    34633.545
# 2012    40084.860
# 2013    35137.118
# 2014    39621.183
# 2015    41208.292
# 2016    42212.229
# 2017    36619.624
# Name: number, dtype: float64

# %%
data2=data.groupby('year')['number'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='year',y='number',data=data2)
# Out:
# <Axes: xlabel='year', ylabel='number'>

# %%
data2
# Out:
#     year     number
# 0   2003  42760.674
# 1   2016  42212.229
# 2   2015  41208.292
# 3   2012  40084.860
# 4   2014  39621.183
# 5   2009  39116.178
# 6   2004  38450.163
# 7   2002  37390.600
# 8   2010  37037.449
# 9   2017  36619.624
# 10  2013  35137.118
# 11  2005  35004.965
# 12  2011  34633.545
# 13  2006  33824.161
# 14  2007  33028.413
# 15  2008  29378.964
# 16  2001  29054.612
# 17  2000  27351.251
# 18  1999  26882.821
# 19  1998  20013.971

# %% [markdown]
# ### In which state Maximum number of forest fires were reported?

# %%
data.groupby('state')['number'].sum()
# Out:
# state
# Acre                18464.030
# Alagoas              4606.000
# Amapa               21831.576
# Amazonas            30650.129
# Bahia               44746.226
# Ceara               30428.063
# Distrito Federal     3561.000
# Espirito Santo       6546.000
# Goias               37695.520
# Maranhao            25129.131
# Mato Grosso         96246.028
# Minas Gerais        37475.258
# Paraiba             52426.918
# Pará                24512.144
# Pernambuco          24498.000
# Piau                37803.747
# Rio                 45094.865
# Rondonia            20285.429
# Roraima             24385.074
# Santa Catarina      24359.852
# Sao Paulo           51121.198
# Sergipe              3237.000
# Tocantins           33707.885
# Name: number, dtype: float64

# %%
data3=data.groupby('state')['number'].sum().reset_index()

# %%
data3
# Out:
#                state     number
# 0               Acre  18464.030
# 1            Alagoas   4606.000
# 2              Amapa  21831.576
# 3           Amazonas  30650.129
# 4              Bahia  44746.226
# 5              Ceara  30428.063
# 6   Distrito Federal   3561.000
# 7     Espirito Santo   6546.000
# 8              Goias  37695.520
# 9           Maranhao  25129.131
# 10       Mato Grosso  96246.028
# 11      Minas Gerais  37475.258
# 12           Paraiba  52426.918
# 13              Pará  24512.144
# 14        Pernambuco  24498.000
# 15              Piau  37803.747
# 16               Rio  45094.865
# 17          Rondonia  20285.429
# 18           Roraima  24385.074
# 19    Santa Catarina  24359.852
# 20         Sao Paulo  51121.198
# 21           Sergipe   3237.000
# 22         Tocantins  33707.885

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='state',y='number',data=data3)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Find total number of fires reported in amazonas

# %%
data.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'month_new'], dtype='object')

# %%
data['state'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)

# %%
data[data['state']=='Amazonas']['number'].sum()
# Out:
# 30650.129

# %% [markdown]
# ### Display number of fires reported in amazonas(year-wise)

# %%
data_amz=data[data['state']=='Amazonas']

# %%
data_amz.groupby('year')['number']

# %%
data_amz.groupby('year')['number'].sum()
# Out:
# year
# 1998     946.000
# 1999    1061.000
# 2000     853.000
# 2001    1297.000
# 2002    2852.000
# 2003    1524.268
# 2004    2298.207
# 2005    1657.128
# 2006     997.640
# 2007     589.601
# 2008    2717.000
# 2009    1320.601
# 2010    2324.508
# 2011    1652.538
# 2012    1110.641
# 2013     905.217
# 2014    2385.909
# 2015    1189.994
# 2016    2060.972
# 2017     906.905
# Name: number, dtype: float64

# %%
data5=data_amz.groupby('year')['number'].sum().reset_index()

# %%
data5
# Out:
#     year    number
# 0   1998   946.000
# 1   1999  1061.000
# 2   2000   853.000
# 3   2001  1297.000
# 4   2002  2852.000
# 5   2003  1524.268
# 6   2004  2298.207
# 7   2005  1657.128
# 8   2006   997.640
# 9   2007   589.601
# 10  2008  2717.000
# 11  2009  1320.601
# 12  2010  2324.508
# 13  2011  1652.538
# 14  2012  1110.641
# 15  2013   905.217
# 16  2014  2385.909
# 17  2015  1189.994
# 18  2016  2060.972
# 19  2017   906.905

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='year',y='number',data=data5)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Display number of fires were reported in amazonas(day-wise)

# %%
data.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'month_new'], dtype='object')

# %%
data['date']
# Out:
# 0      1998-01-01
# 1      1999-01-01
# 2      2000-01-01
# 3      2001-01-01
# 4      2002-01-01
#           ...
# 6449   2012-01-01
# 6450   2013-01-01
# 6451   2014-01-01
# 6452   2015-01-01
# 6453   2016-01-01
# Name: date, Length: 6422, dtype: datetime64[ns]

# %%
data['date'].unique()
# Out:
# array(['1998-01-01T00:00:00.000000000', '1999-01-01T00:00:00.000000000',
#        '2000-01-01T00:00:00.000000000', '2001-01-01T00:00:00.000000000',
#        '2002-01-01T00:00:00.000000000', '2003-01-01T00:00:00.000000000',
#        '2004-01-01T00:00:00.000000000', '2005-01-01T00:00:00.000000000',
#        '2006-01-01T00:00:00.000000000', '2007-01-01T00:00:00.000000000',
#        '2008-01-01T00:00:00.000000000', '2009-01-01T00:00:00.000000000',
#        '2010-01-01T00:00:00.000000000', '2011-01-01T00:00:00.000000000',
#        '2012-01-01T00:00:00.000000000', '2013-01-01T00:00:00.000000000',
#        '2014-01-01T00:00:00.000000000', '2015-01-01T00:00:00.000000000',
#        '2016-01-01T00:00:00.000000000', '2017-01-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
data['date'].value_counts()
# Out:
# 2015-01-01    324
# 2010-01-01    324
# 2000-01-01    324
# 2014-01-01    324
# 2002-01-01    324
# 2003-01-01    324
# 2005-01-01    324
# 2012-01-01    324
# 2016-01-01    324
# 1999-01-01    324
# 2011-01-01    324
# 2013-01-01    323
# 2008-01-01    323
# 2009-01-01    323
# 2006-01-01    323
# 2004-01-01    323
# 2007-01-01    322
# 2001-01-01    321
# 1998-01-01    304
# 2017-01-01    296
# Name: date, dtype: int64

# %%
data.head()
# Out:
#    year state    month  number       date month_new
# 0  1998  Acre  Janeiro     0.0 1998-01-01       jan
# 1  1999  Acre  Janeiro     0.0 1999-01-01       jan
# 2  2000  Acre  Janeiro     0.0 2000-01-01       jan
# 3  2001  Acre  Janeiro     0.0 2001-01-01       jan
# 4  2002  Acre  Janeiro     0.0 2002-01-01       jan

# %%
data6=data[data['state']=='Amazonas']

# %%
data6
# Out:
#      year     state     month  number       date month_new
# 718  1998  Amazonas   Janeiro     0.0 1998-01-01       jan
# 719  1999  Amazonas   Janeiro     3.0 1999-01-01       jan
# 720  2000  Amazonas   Janeiro     7.0 2000-01-01       jan
# 721  2001  Amazonas   Janeiro     3.0 2001-01-01       jan
# 722  2002  Amazonas   Janeiro    17.0 2002-01-01       jan
# ..    ...       ...       ...     ...        ...       ...
# 952  2012  Amazonas  Dezembro    80.0 2012-01-01       dec
# 953  2013  Amazonas  Dezembro   236.0 2013-01-01       dec
# 954  2014  Amazonas  Dezembro   293.0 2014-01-01       dec
# 955  2015  Amazonas  Dezembro   565.0 2015-01-01       dec
# 956  2016  Amazonas  Dezembro   133.0 2016-01-01       dec
#
# [239 rows x 6 columns]

# %%
data6.groupby(data6['date'].dt.dayofweek).sum().number
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3704\3087529959.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data6.groupby(data6['date'].dt.dayofweek).sum().number
# date
# 0    1886.601
# 1    6474.217
# 2    3910.177
# 3    5754.802
# 4    5446.480
# 5    4162.666
# 6    3015.186
# Name: number, dtype: float64

# %%
data6['date'].dt

# %%
data6['date'].dt.dayofweek
# Out:
# 718    3
# 719    4
# 720    5
# 721    0
# 722    1
#       ..
# 952    6
# 953    1
# 954    2
# 955    3
# 956    4
# Name: date, Length: 239, dtype: int64

# %%
data6[data6['date'].dt.dayofweek==0]    #0 means monday
# Out:
#      year     state      month   number       date month_new
# 721  2001  Amazonas    Janeiro    3.000 2001-01-01       jan
# 727  2007  Amazonas    Janeiro   37.000 2007-01-01       jan
# 741  2001  Amazonas  Fevereiro    8.000 2001-01-01       feb
# 747  2007  Amazonas  Fevereiro   92.000 2007-01-01       feb
# 761  2001  Amazonas      Março    6.000 2001-01-01       mar
# 767  2007  Amazonas      Março    6.000 2007-01-01       mar
# 781  2001  Amazonas      Abril    1.000 2001-01-01       apr
# 787  2007  Amazonas      Abril    0.000 2007-01-01       apr
# 801  2001  Amazonas       Maio    0.000 2001-01-01       may
# 807  2007  Amazonas       Maio    0.000 2007-01-01       may
# 821  2001  Amazonas      Junho    5.000 2001-01-01       jun
# 827  2007  Amazonas      Junho   23.000 2007-01-01       jun
# 841  2001  Amazonas      Julho    9.000 2001-01-01       jul
# 847  2007  Amazonas      Julho  116.000 2007-01-01       jul
# ...

# %%
data6[data6['date'].dt.dayofweek==3]      # 3 means thursday
# Out:
#      year     state      month   number       date month_new
# 718  1998  Amazonas    Janeiro    0.000 1998-01-01       jan
# 724  2004  Amazonas    Janeiro  123.000 2004-01-01       jan
# 729  2009  Amazonas    Janeiro    9.000 2009-01-01       jan
# 735  2015  Amazonas    Janeiro   35.000 2015-01-01       jan
# 738  1998  Amazonas  Fevereiro    0.000 1998-01-01       feb
# 744  2004  Amazonas  Fevereiro   92.000 2004-01-01       feb
# 749  2009  Amazonas  Fevereiro    3.000 2009-01-01       feb
# 755  2015  Amazonas  Fevereiro  107.000 2015-01-01       feb
# 758  1998  Amazonas      Março    0.000 1998-01-01       mar
# 764  2004  Amazonas      Março    6.000 2004-01-01       mar
# 769  2009  Amazonas      Março   11.000 2009-01-01       mar
# 775  2015  Amazonas      Março   46.000 2015-01-01       mar
# 778  1998  Amazonas      Abril    0.000 1998-01-01       apr
# 784  2004  Amazonas      Abril    4.000 2004-01-01       apr
# ...

# %%
data6.groupby(data6['date'].dt.dayofweek).sum()['number']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3704\1503756001.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data6.groupby(data6['date'].dt.dayofweek).sum()['number']
# date
# 0    1886.601
# 1    6474.217
# 2    3910.177
# 3    5754.802
# 4    5446.480
# 5    4162.666
# 6    3015.186
# Name: number, dtype: float64

# %%
import calendar
calendar.day_name[0]
# Out:
# 'Monday'

# %%
[calendar.day_name[x] for x in range(0,7)]
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
day=data6.groupby(data6['date'].dt.dayofweek).sum()['number']
day.index=[calendar.day_name[x] for x in range(0,7)]
day
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3704\4048338770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   day=data6.groupby(data6['date'].dt.dayofweek).sum()['number']
# Monday       1886.601
# Tuesday      6474.217
# Wednesday    3910.177
# Thursday     5754.802
# Friday       5446.480
# Saturday     4162.666
# Sunday       3015.186
# Name: number, dtype: float64

# %%
day=day.reset_index()

# %%
sns.barplot(x='index',y='number',data=day)
# Out:
# <Axes: xlabel='index', ylabel='number'>

# %% [markdown]
# #### Find total number of fires were reported in 2015 and visualize data based on each "month"

# %%
data7=data[data['year']==2015]

# %%
data7
# Out:
#       year      state      month   number       date month_new
# 17    2015       Acre    Janeiro    1.000 2015-01-01       jan
# 37    2015       Acre  Fevereiro    2.000 2015-01-01       feb
# 57    2015       Acre      Março    2.000 2015-01-01       mar
# 77    2015       Acre      Abril    3.000 2015-01-01       apr
# 97    2015       Acre       Maio    2.000 2015-01-01       may
# ...    ...        ...        ...      ...        ...       ...
# 6372  2015  Tocantins     Agosto    2.540 2015-01-01       aug
# 6392  2015  Tocantins   Setembro    5.510 2015-01-01       sep
# 6412  2015  Tocantins    Outubro    4.844 2015-01-01       oct
# 6432  2015  Tocantins   Novembro  833.000 2015-01-01       nov
# 6452  2015  Tocantins   Dezembro  373.000 2015-01-01       dec
#
# [324 rows x 6 columns]

# %%
data[data['year']==2015]['number'].sum()
# Out:
# 41208.292

# %%
data7.groupby('month_new')['number']

# %%
data7.groupby('month_new')['number'].sum()
# Out:
# month_new
# apr    2573.000
# aug    4363.125
# dec    4088.522
# feb    2309.000
# jan    4635.000
# jul    4364.392
# jun    3260.552
# mar    2202.000
# may    2384.000
# nov    4034.518
# oct    4499.525
# sep    2494.658
# Name: number, dtype: float64

# %%
fire=data7.groupby('month_new')['number'].sum().sort_values(ascending=False).reset_index()

# %%
fire
# Out:
#    month_new    number
# 0        jan  4635.000
# 1        oct  4499.525
# 2        jul  4364.392
# 3        aug  4363.125
# 4        dec  4088.522
# 5        nov  4034.518
# 6        jun  3260.552
# 7        apr  2573.000
# 8        sep  2494.658
# 9        may  2384.000
# 10       feb  2309.000
# 11       mar  2202.000

# %%
sns.barplot(x='month_new',y='number',data=fire)
# Out:
# <Axes: xlabel='month_new', ylabel='number'>

# %%
sns.barplot(x='month_new',y='number',data=data7)
# Out:
# <Axes: xlabel='month_new', ylabel='number'>

# %% [markdown]
# #### Find average number of fires were reported from highest to lowest (State-Wise)

# %%
data.groupby('state')['number']

# %%
data.groupby('state')['number'].mean()
# Out:
# state
# Acre                 77.255356
# Alagoas              19.271967
# Amapa                91.345506
# Amazonas            128.243218
# Bahia               187.222703
# Ceara               127.314071
# Distrito Federal     14.899582
# Espirito Santo       27.389121
# Goias               157.721841
# Maranhao            105.142808
# Mato Grosso         203.479975
# Minas Gerais        156.800243
# Paraiba             111.073979
# Pará                102.561272
# Pernambuco          102.502092
# Piau                158.174674
# Rio                  64.698515
# Rondonia             84.876272
# Roraima             102.029598
# Santa Catarina      101.924067
# Sao Paulo           213.896226
# Sergipe              13.543933
# Tocantins           141.037176
# Name: number, dtype: float64

# %%
data.groupby('state')['number'].mean().sort_values(ascending=False)
# Out:
# state
# Sao Paulo           213.896226
# Mato Grosso         203.479975
# Bahia               187.222703
# Piau                158.174674
# Goias               157.721841
# Minas Gerais        156.800243
# Tocantins           141.037176
# Amazonas            128.243218
# Ceara               127.314071
# Paraiba             111.073979
# Maranhao            105.142808
# Pará                102.561272
# Pernambuco          102.502092
# Roraima             102.029598
# Santa Catarina      101.924067
# Amapa                91.345506
# Rondonia             84.876272
# Acre                 77.255356
# Rio                  64.698515
# Espirito Santo       27.389121
# Alagoas              19.271967
# Distrito Federal     14.899582
# Sergipe              13.543933
# Name: number, dtype: float64

# %%
data7=data.groupby('state')['number'].mean().sort_values(ascending=False).reset_index()

# %%
data7
# Out:
#                state      number
# 0          Sao Paulo  213.896226
# 1        Mato Grosso  203.479975
# 2              Bahia  187.222703
# 3               Piau  158.174674
# 4              Goias  157.721841
# 5       Minas Gerais  156.800243
# 6          Tocantins  141.037176
# 7           Amazonas  128.243218
# 8              Ceara  127.314071
# 9            Paraiba  111.073979
# 10          Maranhao  105.142808
# 11              Pará  102.561272
# 12        Pernambuco  102.502092
# 13           Roraima  102.029598
# 14    Santa Catarina  101.924067
# 15             Amapa   91.345506
# 16          Rondonia   84.876272
# 17              Acre   77.255356
# 18               Rio   64.698515
# 19    Espirito Santo   27.389121
# 20           Alagoas   19.271967
# 21  Distrito Federal   14.899582
# 22           Sergipe   13.543933

# %%
sns.barplot(x='state',y='number',data=data7)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### To find the state names where fires were reported in december month

# %%
data.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date', 'month_new'], dtype='object')

# %%
data10=data[data['month_new']=='dec']

# %%
data10
# Out:
#       year      state     month  number       date month_new
# 220   1998       Acre  Dezembro     7.0 1998-01-01       dec
# 221   1999       Acre  Dezembro     0.0 1999-01-01       dec
# 222   2000       Acre  Dezembro     0.0 2000-01-01       dec
# 223   2001       Acre  Dezembro     0.0 2001-01-01       dec
# 224   2002       Acre  Dezembro     1.0 2002-01-01       dec
# ...    ...        ...       ...     ...        ...       ...
# 6449  2012  Tocantins  Dezembro   128.0 2012-01-01       dec
# 6450  2013  Tocantins  Dezembro    85.0 2013-01-01       dec
# 6451  2014  Tocantins  Dezembro   223.0 2014-01-01       dec
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01       dec
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01       dec
#
# [513 rows x 6 columns]

# %%
data10[data10['month_new']=='dec']['state']
# Out:
# 220          Acre
# 221          Acre
# 222          Acre
# 223          Acre
# 224          Acre
#           ...
# 6449    Tocantins
# 6450    Tocantins
# 6451    Tocantins
# 6452    Tocantins
# 6453    Tocantins
# Name: state, Length: 513, dtype: object

# %%
data10['state'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)

# %%
len(data10['state'].unique())
# Out:
# 23

# %%
l1=[]
for value in data10['state']:
    if value not in l1:
        l1.append(value)

# %%
l1
# Out:
# ['Acre',
#  'Alagoas',
#  'Amapa',
#  'Amazonas',
#  'Bahia',
#  'Ceara',
#  'Distrito Federal',
#  'Espirito Santo',
#  'Goias',
#  'Maranhao',
#  'Mato Grosso',
#  'Minas Gerais',
#  'Pará',
#  'Paraiba',
#  'Pernambuco',
#  'Piau',
#  'Rio',
#  'Rondonia',
#  'Roraima',
#  'Santa Catarina',
#  'Sao Paulo',
#  'Sergipe',
#  'Tocantins']

# %%
len(l1)
# Out:
# 23

# %%
l2=[]
for value in data10['state']:
    l2.append(value)

# %%
len(l2)
# Out:
# 513

# %%
l2
# Out:
# ['Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Acre',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Alagoas',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amapa',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Amazonas',
#  'Bahia',
# ...

# %%
from collections import Counter

# %%
Counter(l2)
# Out:
# Counter({'Acre': 19,
#          'Alagoas': 19,
#          'Amapa': 19,
#          'Amazonas': 19,
#          'Bahia': 19,
#          'Ceara': 19,
#          'Distrito Federal': 19,
#          'Espirito Santo': 19,
#          'Goias': 19,
#          'Maranhao': 19,
#          'Mato Grosso': 38,
#          'Minas Gerais': 19,
#          'Pará': 19,
#          'Paraiba': 38,
#          'Pernambuco': 19,
#          'Piau': 19,
#          'Rio': 57,
#          'Rondonia': 19,
#          'Roraima': 19,
#          'Santa Catarina': 19,
#          'Sao Paulo': 19,
#          'Sergipe': 19,
#          'Tocantins': 19})

# %%
data10['state'].value_counts()
# Out:
# Rio                 57
# Mato Grosso         38
# Paraiba             38
# Acre                19
# Pará                19
# Sergipe             19
# Sao Paulo           19
# Santa Catarina      19
# Roraima             19
# Rondonia            19
# Piau                19
# Pernambuco          19
# Minas Gerais        19
# Alagoas             19
# Maranhao            19
# Goias               19
# Espirito Santo      19
# Distrito Federal    19
# Ceara               19
# Bahia               19
# Amazonas            19
# Amapa               19
# Tocantins           19
# Name: state, dtype: int64

# %%
data.shape
# Out:
# (6422, 6)
