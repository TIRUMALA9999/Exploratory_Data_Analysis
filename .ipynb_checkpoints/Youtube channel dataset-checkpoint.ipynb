# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('top-5000-youtube-channels.csv')

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data.tail()
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4,996th   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4,997th   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4,998th   B+         Mastersaint           110     3265735    311758426
# 4998  4,999th   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5,000th   B+           SehatAQUA           254       21172     73312511

# %%
data.shape
# Out:
# (5000, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %%
data.sample()
# Out:
#          Rank Grade  Channel name Video Uploads Subscribers  Video views
# 2902  2,903rd   B+   العاب سيمبا…           474      691078    421290338

# %%
data.sample(5)
# Out:
#          Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4042  4,043rd   B+             Вайнран           568     1543962    495469730
# 4361  4,362nd   B+         Olsa & Olta             7      160691     53907404
# 2064  2,065th   B+      PS TAMIL SONGS          2936         --     243626688
# 4964  4,965th   B+                 슈기님          1134     1454553    365489767
# 3613  3,614th   B+   SmallroomOfficial          1175     1373468   1161766584

# %%
data.describe(include='all')
# Out:
#         Rank Grade Channel name Video Uploads Subscribers   Video views
# count   5000  5000         5000          5000        5000  5.000000e+03
# unique  5000     6         4993          2286        4612           NaN
# top      1st   B+    Thơ Nguyễn            26         --            NaN
# freq       1  2956            2            17         387           NaN
# mean     NaN   NaN          NaN           NaN         NaN  1.071449e+09
# std      NaN   NaN          NaN           NaN         NaN  2.003844e+09
# min      NaN   NaN          NaN           NaN         NaN  7.500000e+01
# 25%      NaN   NaN          NaN           NaN         NaN  1.862329e+08
# 50%      NaN   NaN          NaN           NaN         NaN  4.820548e+08
# 75%      NaN   NaN          NaN           NaN         NaN  1.124368e+09
# max      NaN   NaN          NaN           NaN         NaN  4.754884e+10

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data['Subscribers'].max()
# Out:
# '9998464'

# %%
data['Subscribers']==data['Subscribers'].max()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: Subscribers, Length: 5000, dtype: bool

# %%
data[data['Subscribers']==data['Subscribers'].max()]
# Out:
#          Rank Grade Channel name Video Uploads Subscribers  Video views
# 1002  1,003rd    A       BIGBANG           769     9998464   4756874954

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', '\xa0 ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade']
# Out:
# 0       A++
# 1       A++
# 2       A++
# 3       A++
# 4       A++
#         ...
# 4995     B+
# 4996     B+
# 4997     B+
# 4998     B+
# 4999     B+
# Name: Grade, Length: 5000, dtype: object

# %%
data['Grade']== 'A++ '
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: Grade, Length: 5000, dtype: bool

# %%
data[data['Grade']=='A++ ']
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0   1st  A++                       Zee TV         82757    18752951
# 1   2nd  A++                     T-Series         12661    61196302
# 2   3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3   4th  A++                    SET India         27323    31180559
# 4   5th  A++                          WWE         36756    32852346
# 5   6th  A++                   Movieclips         30243    17149705
# 6   7th  A++                   netd müzik          8500    11373567
# 7   8th  A++        ABS-CBN Entertainment        100147    12149206
# 8   9th  A++              Ryan ToysReview          1140    16082927
# 9  10th  A++                  Zee Marathi         74607     2841811
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433
# 5  16618094724
# 6  23898730764
# 7  17202609850
# 8  24518098041
# 9   2591830307

# %%
data[data['Grade']=='A++ '].shape
# Out:
# (10, 6)

# %%
data[data['Grade']=='A++ ']['Channel name']
# Out:
# 0                        Zee TV
# 1                      T-Series
# 2    Cocomelon - Nursery Rhymes
# 3                     SET India
# 4                           WWE
# 5                    Movieclips
# 6                    netd müzik
# 7         ABS-CBN Entertainment
# 8               Ryan ToysReview
# 9                   Zee Marathi
# Name: Channel name, dtype: object

# %%
data['Grade'].value_counts()
# Out:
# B+      2956
# A-      1024
# A        963
# A+        41
# A++       10
#            6
# Name: Grade, dtype: int64

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', '\xa0 ', 'A- ', 'B+ '], dtype=object)

# %%
data[data['Grade']=='\xa0 ']
# Out:
#          Rank Grade                  Channel name Video Uploads Subscribers  \
# 267     268th                    MidnightXChannel            --         --
# 517     518th                      Dusama Pets TV            --         --
# 2323  2,324th                              Random            --       12275
# 3072  3,073rd        Boram Tube Toy Shcool [보람튜브…            --      726527
# 3247  3,248th                       atheer sultan            --         --
# 4898  4,899th                        ExzoticSlice            --       99785
#
#       Video views
# 267     190256974
# 517      91601494
# 2323     17897584
# 3072    205555289
# 3247     79663674
# 4898      9745292

# %%
data['Video Uploads'].max()
# Out:
# '999'

# %%
data['Video Uploads'].min()
# Out:
# '--'

# %%
data[data['Video Uploads']=='--']
# Out:
#          Rank Grade                  Channel name Video Uploads Subscribers  \
# 267     268th                    MidnightXChannel            --         --
# 517     518th                      Dusama Pets TV            --         --
# 2323  2,324th                              Random            --       12275
# 3072  3,073rd        Boram Tube Toy Shcool [보람튜브…            --      726527
# 3247  3,248th                       atheer sultan            --         --
# 4898  4,899th                        ExzoticSlice            --       99785
#
#       Video views
# 267     190256974
# 517      91601494
# 2323     17897584
# 3072    205555289
# 3247     79663674
# 4898      9745292

# %%
data['Video views'].max()
# Out:
# 47548839843

# %%
data[data['Grade']=='\xa0 ']['Video views'].mean()
# Out:
# 99120051.16666667

# %%
data.shape
# Out:
# (5000, 6)

# %%
data.drop(267,axis=0)
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data.drop([517,2323,3072,3247,4898],axis=0)
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data=data.drop([267,517,2323,3072,3247,4898],axis=0)

# %%
data.shape
# Out:
# (4994, 6)

# %%
data[data['Grade']=='\xa0 ']
# Out:
# Empty DataFrame
# Columns: [Rank, Grade, Channel name, Video Uploads, Subscribers, Video views]
# Index: []

# %%
data.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data['Grade'].value_counts()
# Out:
# B+      2956
# A-      1024
# A        963
# A+        41
# A++       10
# Name: Grade, dtype: int64

# %%
sns.countplot(x=data['Grade'],data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='count'>

# %%
data[data['Subscribers'].str.contains('-- ')]
# Out:
#          Rank Grade                   Channel name Video Uploads Subscribers  \
# 17       18th   A+                 Vlad and Nikita            53         --
# 108     109th    A                          BIGFUN           373         --
# 115     116th    A    Bee Kids Games - Children TV           740         --
# 142     143rd    A             ChiChi TV Siêu Nhân           421         --
# 143     144th    A                  MusicTalentNow          1487         --
# ...       ...   ...                            ...           ...         ...
# 4941  4,942nd   B+                            GMTV           183         --
# 4948  4,949th   B+               Keivon ToysReview           468         --
# 4956  4,957th   B+                       CLICKNEWS          2661         --
# 4961  4,962nd   B+                ONE Championship           905         --
# 4990  4,991st   B+   Ho Ngoc Ha's Official Channel           208         --
#
#       Video views
# 17     1428274554
# ...

# %%
data.iloc[17]
# Out:
# Rank                        18th
# Grade                        A+
# Channel name     Vlad and Nikita
# Video Uploads                 53
# Subscribers                  --
# Video views           1428274554
# Name: 17, dtype: object

# %%
data['Video Uploads']
# Out:
# 0       82757
# 1       12661
# 2         373
# 3       27323
# 4       36756
#         ...
# 4995      706
# 4996      797
# 4997      110
# 4998     3475
# 4999      254
# Name: Video Uploads, Length: 4994, dtype: object

# %%
data['Video Uploads']=data['Video Uploads'].astype(int)

# %%
data['Video Uploads'].dtype
# Out:
# dtype('int32')

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Video Uploads   Video views
# count    4994.000000  4.994000e+03
# mean     3859.463556  1.072618e+09
# std     17085.866498  2.004762e+09
# min         1.000000  7.500000e+01
# 25%       141.000000  1.863155e+08
# 50%       443.000000  4.824501e+08
# 75%      1501.750000  1.124961e+09
# max    422326.000000  4.754884e+10

# %%
pd.options.display.float_format='{:.3f}'.format

# %%
data.describe()
# Out:
#        Video Uploads     Video views
# count       4994.000        4994.000
# mean        3859.464  1072617597.205
# std        17085.866  2004762201.209
# min            1.000          75.000
# 25%          141.000   186315479.250
# 50%          443.000   482450118.500
# 75%         1501.750  1124960779.750
# max       422326.000 47548839843.000

# %%
data.head(-5)   # It displays all rows except last five rows
# Out:
#          Rank Grade                      Channel name  Video Uploads  \
# 0         1st  A++                             Zee TV          82757
# 1         2nd  A++                           T-Series          12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes            373
# 3         4th  A++                          SET India          27323
# 4         5th  A++                                WWE          36756
# ...       ...   ...                               ...            ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel            208
# 4991  4,992nd   B+               Toys to Learn Colors             11
# 4992  4,993rd   B+                              КАZКА             25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…           1055
# 4994  4,995th   B+                      Wings Marathi           1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
data.tail(-5)       #It displays all rows except first five rows
# Out:
#          Rank Grade           Channel name  Video Uploads Subscribers  \
# 5         6th  A++              Movieclips          30243    17149705
# 6         7th  A++              netd müzik           8500    11373567
# 7         8th  A++   ABS-CBN Entertainment         100147    12149206
# 8         9th  A++         Ryan ToysReview           1140    16082927
# 9        10th  A++             Zee Marathi          74607     2841811
# ...       ...   ...                    ...            ...         ...
# 4995  4,996th   B+          Uras Benlioğlu            706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD            797     1055091
# 4997  4,998th   B+             Mastersaint            110     3265735
# 4998  4,999th   B+          Bruce McIntosh           3475       32990
# 4999  5,000th   B+               SehatAQUA            254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...

# %% [markdown]
# ##### Data cleaning (Replace '--'  to NaN)

# %%
data=data.replace('--',np.nan,regex=True)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name  Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV          82757    18752951
# 1    2nd  A++                     T-Series          12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes            373    19238251
# 3    4th  A++                    SET India          27323    31180559
# 4    5th  A++                          WWE          36756    32852346
# 5    6th  A++                   Movieclips          30243    17149705
# 6    7th  A++                   netd müzik           8500    11373567
# 7    8th  A++        ABS-CBN Entertainment         100147    12149206
# 8    9th  A++              Ryan ToysReview           1140    16082927
# 9   10th  A++                  Zee Marathi          74607     2841811
# 10  11th   A+              5-Minute Crafts           2085    33492951
# 11  12th   A+              Canal KondZilla            822    39409726
# ...

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      0
# Subscribers      384
# Video views        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna(axis=0,inplace=True)

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['Rank']
# Out:
# 0           1st
# 1           2nd
# 2           3rd
# 3           4th
# 4           5th
#          ...
# 4995    4,996th
# 4996    4,997th
# 4997    4,998th
# 4998    4,999th
# 4999    5,000th
# Name: Rank, Length: 4610, dtype: object

# %%
data['Rank']=data['Rank'].str[:-2]

# %%
data['Rank']
# Out:
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
#         ...
# 4995    4,996
# 4996    4,997
# 4997    4,998
# 4998    4,999
# 4999    5,000
# Name: Rank, Length: 4610, dtype: object

# %%
data['Rank']=data['Rank'].str.replace(',','')

# %%
data['Rank']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 4995    4996
# 4996    4997
# 4997    4998
# 4998    4999
# 4999    5000
# Name: Rank, Length: 4610, dtype: object

# %%
data['Rank'].dtype
# Out:
# dtype('O')

# %%
data['Rank']=data['Rank'].astype(int)

# %%
data['Rank'].dtype
# Out:
# dtype('int32')

# %%
data['Subscribers'].dtype
# Out:
# dtype('O')

# %%
data['Subscribers']=data['Subscribers'].astype(int)

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int64
# dtype: object

# %%
data['Grade']
# Out:
# 0       A++
# 1       A++
# 2       A++
# 3       A++
# 4       A++
#         ...
# 4995     B+
# 4996     B+
# 4997     B+
# 4998     B+
# 4999     B+
# Name: Grade, Length: 4610, dtype: object

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4995    1
# 4996    1
# 4997    1
# 4998    1
# 4999    1
# Name: Grade, Length: 4610, dtype: int64

# %%
data['Grade']=data['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})

# %%
data['Grade'].dtype
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade             int64
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int64
# dtype: object

# %% [markdown]
# #### Find average views for each channel

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data['Avg_views']=data['Video views']/data['Video Uploads']

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views    Avg_views
# 0  20869786591   252181.527
# 1  47548839843  3755535.885
# 2   9793305082 26255509.603
# 3  22675948293   829921.615
# 4  26273668433   714813.049

# %% [markdown]
# #### Find out top 5 channels with maximum number of video uploads

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Avg_views'],
#       dtype='object')

# %%
data.sort_values(by='Video Uploads',ascending=False)
# Out:
#       Rank  Grade        Channel name  Video Uploads  Subscribers  \
# 3453  3454      1          AP Archive         422326       746325
# 1149  1150      2            YTN NEWS         355996       820108
# 2223  2224      1           SBS Drama         335521      1418619
# 323    324      3            GMA News         269065      2599175
# 2956  2957      1                 MLB         267649      1434206
# ...    ...    ...                 ...            ...          ...
# 4100  4101      1     DenzelCurryVEVO              1         8012
# 2404  2405      1  ItsHARSH007 Gaming              1        23499
# 4474  4475      1           hyghhopes              1        15325
# 628    629      3          cocoz toon              1      2162992
# 4975  4976      1          Funny Kids              1       150091
#
#       Video views     Avg_views
# 3453    548619569      1299.043
# 1149   1640347646      4607.770
# 2223   1565758044      4666.647
# 323    2786949164     10357.903
# ...

# %%
data.sort_values(by='Video Uploads',ascending=False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175   2786949164
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Avg_views
# 3453   1299.043
# 1149   4607.770
# 2223   4666.647
# 323   10357.903
# 2956   4966.230

# %%
data.sort_values(by='Video Uploads',ascending=False).head()['Channel name']
# Out:
# 3453    AP Archive
# 1149      YTN NEWS
# 2223     SBS Drama
# 323       GMA News
# 2956           MLB
# Name: Channel name, dtype: object

# %% [markdown]
# #### find correlation matrix

# %%
data.corr()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9448\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 Rank  Grade  Video Uploads  Subscribers  Video views  \
# Rank           1.000 -0.865         -0.073       -0.383       -0.403
# Grade         -0.865  1.000          0.089        0.429        0.477
# Video Uploads -0.073  0.089          1.000        0.011        0.088
# Subscribers   -0.383  0.429          0.011        1.000        0.791
# Video views   -0.403  0.477          0.088        0.791        1.000
# Avg_views     -0.154  0.155         -0.064        0.289        0.294
#
#                Avg_views
# Rank              -0.154
# Grade              0.155
# Video Uploads     -0.064
# Subscribers        0.289
# Video views        0.294
# Avg_views          1.000

# %% [markdown]
# #### Which grade has a maximum number of video uploads?

# %%
sns.barplot(x=data['Grade'],y=data['Video Uploads'],data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %%
sns.barplot(x='Grade',y='Video Uploads',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %% [markdown]
# #### Which grade has the highest average views

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Avg_views'],
#       dtype='object')

# %%
sns.barplot(x=data['Grade'],y=data['Avg_views'],data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Avg_views'>

# %% [markdown]
# #### Which grade has the highest number of subscribers

# %%
sns.barplot(x=data['Grade'],y=data['Subscribers'],data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Subscribers'>

# %% [markdown]
# #### Which grade has the highest video views

# %%
sns.barplot(x=data['Grade'],y=data['Video views'],data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video views'>

# %%
data.groupby('Grade').mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_9448\3670195322.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Grade').mean()
#           Rank  Video Uploads  Subscribers     Video views    Avg_views
# Grade
# 1     3520.538       3136.157  1535207.947   555183839.086  3280380.878
# 2     1533.988       4382.582  2798520.375  1102450027.687  5254804.044
# 3      534.285       5709.855  5107136.294  2497972949.111 10540908.455
# 4       31.325      16960.300 11726947.475  6168741772.725 11577080.322
# 5        5.500      37450.700 22281762.500 21199091192.800  5688267.963
