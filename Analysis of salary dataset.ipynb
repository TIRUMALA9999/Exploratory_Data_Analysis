# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.temperature.max()
# Out:
# 35

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df[['day','temperature']][df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
[df['temperature']==df['temperature'].max()]
# Out:
# [0    False
#  1     True
#  2    False
#  3    False
#  4    False
#  5    False
#  Name: temperature, dtype: bool]

# %%
df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index('event',inplace=True)

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.iloc[:,:-1]
# Out:
#             day  temperature
# event
# Rain   1/1/2017           32
# Sunny  1/2/2017           35
# Snow   1/3/2017           28
# Snow   1/4/2017           24
# Rain   1/5/2017           32
# Sunny  1/6/2017           31

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017           32          6
# 1  Sunny  1/2/2017           35          7
# 2   Snow  1/3/2017           28          2
# 3   Snow  1/4/2017           24          7
# 4   Rain  1/5/2017           32          4
# 5  Sunny  1/6/2017           31          2

# %%
df.loc[df['event']=='Rain']
# Out:
#   event       day  temperature  windspeed
# 0  Rain  1/1/2017           32          6
# 4  Rain  1/5/2017           32          4

# %%
df.loc[df['temperature']==df['temperature'].max()]
# Out:
#    event       day  temperature  windspeed
# 1  Sunny  1/2/2017           35          7

# %%
df['windspeed'].value_counts()
# Out:
# 7    2
# 2    2
# 6    1
# 4    1
# Name: windspeed, dtype: int64

# %%
df.loc[df['windspeed'].value_counts()]
# Out:
#    event       day  temperature  windspeed
# 2   Snow  1/3/2017           28          2
# 2   Snow  1/3/2017           28          2
# 1  Sunny  1/2/2017           35          7
# 1  Sunny  1/2/2017           35          7

# %%
data=pd.read_csv('Salaries.csv')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18528\3456294925.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('Salaries.csv')

# %%
data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
data.shape
# Out:
# (148654, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
data.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
data['BasePay'].dtype
# Out:
# dtype('O')

# %%
data['TotalPay'].dtype
# Out:
# dtype('float64')

# %%
data['Year'].dtype
# Out:
# dtype('int64')

# %%
type(data['Year'])
# Out:
# pandas.core.series.Series

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data=data.drop(['Id','Notes', 'Agency','Status'],axis=1)

# %%
data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %%
data.dtypes
# Out:
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['EmployeeName'].value_counts().head()
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %%
data['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
len(data['JobTitle'].unique())
# Out:
# 2159

# %%
data['JobTitle'].nunique()
# Out:
# 2159

# %%
data['JobTitle'].str.contains('Captain',case=False)
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
data[data['JobTitle'].str.contains('Captain',case=False)]
# Out:
#               EmployeeName                               JobTitle    BasePay  \
# 1             GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2           ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)    99722.0
# 17          SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 22           GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION  140546.88
# ...                    ...                                    ...        ...
# 116604   Gregory L Stewart              Captain, Fire Suppression   73355.21
# 120867     Michael J Moran                              Captain 3     7660.0
# 122361  Michael V Rolovich              Captain, Fire Suppression        0.0
# 126588    Stephen M Tittel                              Captain 3   68491.89
# 132232     Jeanne M Seyler              Captain, Fire Suppression   61039.43
#
# ...

# %%
len(data[data['JobTitle'].str.contains('Captain',case=False)])
# Out:
# 552

# %%
data[data['JobTitle'].str.contains('Captain',case=False)].count()
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# dtype: int64

# %% [markdown]
# #### Disply all employee names from fire department

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data["JobTitle"].str.contains('fire department',case=False)]
# Out:
#                 EmployeeName  \
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
# ...                      ...
# 32623           JAMES BARDEN
# 36162     Joanne Hayes-White
# 72926   Joanne M Hayes-White
# 102303        Robert E Evans
# 110535  Joanne M Hayes-White
#
#                                                 JobTitle    BasePay  \
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)   285262.0
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ...                                                  ...        ...
# 32623                 BATTALION CHIEF, (FIRE DEPARTMENT)        0.0
# ...

# %%
data[data["JobTitle"].str.contains('fire department',case=False)]['EmployeeName']
# Out:
# 4              PATRICK GARDNER
# 6                    ALSON LEE
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
#                   ...
# 32623             JAMES BARDEN
# 36162       Joanne Hayes-White
# 72926     Joanne M Hayes-White
# 102303          Robert E Evans
# 110535    Joanne M Hayes-White
# Name: EmployeeName, Length: 226, dtype: object

# %% [markdown]
# #### To find minimum and  maximum and average basepay

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data['BasePay'].isnull().sum()
# Out:
# 605

# %%
import numpy as np

# %%
data[data['BasePay'].isnull()]
# Out:
#              EmployeeName                   JobTitle BasePay OvertimePay  \
# 81391     Kevin P Cashman             Deputy Chief 3     NaN         0.0
# 84506   Demetrya  Mullens  Licensed Vocational Nurse     NaN         0.0
# 84960     Michael M Horan        Park Patrol Officer     NaN         0.0
# 90525        Thomas  Tang           Police Officer 3     NaN         0.0
# 90786      Michael C Hill             Deputy Sheriff     NaN         0.0
# ...                   ...                        ...     ...         ...
# 110526     Arthur L Curry    PS Aide Health Services     NaN         0.0
# 110527      Nereida  Vega               Senior Clerk     NaN         0.0
# 110528   Timothy E Gibson           Police Officer 3     NaN         0.0
# 110529     Mark E Laherty           Police Officer 3     NaN         0.0
# 110530      David P Kucia           Police Officer 3     NaN         0.0
#
#          OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# ...

# %%
data['BasePay']=data['BasePay'].replace(np.NaN,0)

# %%
data['BasePay'].isnull().sum()
# Out:
# 0

# %%
data['BasePay'].describe()
# Out:
# count     148654.0
# unique    109900.0
# top            0.0
# freq        1480.0
# Name: BasePay, dtype: float64

# %%
 data['BasePay'].dtype
# Out:
# dtype('O')

# %%
data[data['BasePay']=='Not Provided']
# Out:
#         EmployeeName      JobTitle       BasePay   OvertimePay      OtherPay  \
# 148646  Not provided  Not provided  Not Provided  Not Provided  Not Provided
# 148650  Not provided  Not provided  Not Provided  Not Provided  Not Provided
# 148651  Not provided  Not provided  Not Provided  Not Provided  Not Provided
# 148652  Not provided  Not provided  Not Provided  Not Provided  Not Provided
#
#             Benefits  TotalPay  TotalPayBenefits  Year
# 148646  Not Provided       0.0               0.0  2014
# 148650  Not Provided       0.0               0.0  2014
# 148651  Not Provided       0.0               0.0  2014
# 148652  Not Provided       0.0               0.0  2014

# %%
data.drop([148650,148651,148652],axis=0,inplace=True)

# %%
data[data['BasePay']=='Not Provided']
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
data['BasePay'].dtype
# Out:
# dtype('O')

# %%
data['BasePay']=data['BasePay'].astype(float)

# %%
data["BasePay"].describe()
# Out:
# count    148650.000000
# mean      66055.506718
# std       42885.919334
# min        -166.010000
# 25%       32798.550000
# 50%       64862.310000
# 75%       94609.715000
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
data['BasePay'].max()
# Out:
# 319275.01

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148645     Carolyn A Wilson
# 148647       Joann Anderson
# 148648          Leon Walker
# 148649        Roy I Tillery
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148650, dtype: object

# %%
data[data['EmployeeName'].isin(['Not Provided'])]
# Out:
#        EmployeeName                                 JobTitle   BasePay  \
# 13797  Not Provided  PUBLIC SAFETY COMMUNICATIONS DISPATCHER  57963.39
# 44151  Not Provided                   Public SafetyComm Disp  82196.52
#
#       OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year
# 13797    19683.91  4373.86      NaN   82021.16          82021.16  2011
# 44151     25934.2  3752.49  38024.3  111883.21         149907.51  2012

# %%
data.iloc[148649]
# Out:
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                    0.0
# OvertimePay                               0.00
# OtherPay                               -618.13
# Benefits                                  0.00
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Name: 148653, dtype: object

# %%
data['EmployeeName']=data['EmployeeName'].replace('Not Provided',np.nan)

# %%
data['EmployeeName'].isnull().sum()
# Out:
# 2

# %%
data[data['EmployeeName'].isnull()]
# Out:
#       EmployeeName                                 JobTitle   BasePay  \
# 13797          NaN  PUBLIC SAFETY COMMUNICATIONS DISPATCHER  57963.39
# 44151          NaN                   Public SafetyComm Disp  82196.52
#
#       OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year
# 13797    19683.91  4373.86      NaN   82021.16          82021.16  2011
# 44151     25934.2  3752.49  38024.3  111883.21         149907.51  2012

# %%
data.drop([13797,44151],axis=0,inplace=True)

# %%
data[data['EmployeeName'].isnull()]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
data.dtypes
# Out:
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# dtype: object

# %%
data.isnull().sum()   # finding the missing values along the columns
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay                 0
# OvertimePay             0
# OtherPay                0
# Benefits            36158
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
data.isnull().sum(axis=1)     # Finding the null values along the rows
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 148645    0
# 148647    0
# 148648    0
# 148649    0
# 148653    0
# Length: 148648, dtype: int64

# %%
data[data.isnull().sum(axis=1)==5]    #Nothing is there because I removed these values before. That's why they are not there
                                     # ''' ==5 indicates that. If there are missing values along the row that are equal to 5. the
                                     #   the query displays the rows'''
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
 data.drop(data[data.isnull().sum(axis=1)==5].index,axis=0,inplace=True)

# %% [markdown]
# #### Find the Job title of Albert pardini

# %%
data[data['EmployeeName']=='ALBERT PARDINI']
# Out:
#      EmployeeName                         JobTitle    BasePay OvertimePay  \
# 2  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
#
#   OtherPay Benefits   TotalPay  TotalPayBenefits  Year
# 2  16452.6      NaN  335279.91         335279.91  2011

# %%
data[data['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
data[data['EmployeeName']=='ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# #### Display name of the person having highest BasePay

# %%
data[data['BasePay']==data['BasePay'].max()]
# Out:
#          EmployeeName         JobTitle    BasePay OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01         0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year
# 72925  86533.21  339282.07         425815.28  2013

# %%
data['BasePay'].max()
# Out:
# 319275.01

# %%
data[data['BasePay']==data['BasePay'].max()]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
data["BasePay"].mean()
# Out:
# 66055.45257036759

# %% [markdown]
# #### Find average base pay of all employees per year

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data.groupby('Year').mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18528\674510616.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Year').mean()
#            BasePay      TotalPay  TotalPayBenefits
# Year
# 2011  63596.112293  71743.819645      71743.819645
# 2012  65435.950986  74112.234931     100551.886807
# 2013  68509.832156  77611.443142     101440.519714
# 2014  66564.421924  75471.836912     100261.438668

# %%
data.groupby('Year').mean()['BasePay']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18528\3282093210.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Year').mean()['BasePay']
# Year
# 2011    63596.112293
# 2012    65435.950986
# 2013    68509.832156
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# #### Find average base pay of all employees per Jobtitle

# %%
data.groupby('JobTitle').mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18528\3795189614.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('JobTitle').mean()
#                                                      BasePay      TotalPay  \
# JobTitle
# ACCOUNT CLERK                                   43300.806506  44035.664337
# ACCOUNTANT                                      46643.172000  47429.268000
# ACCOUNTANT INTERN                               28732.663958  29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000  62290.780000
# ACUPUNCTURIST                                   66374.400000  67594.400000
# ...                                                      ...           ...
# X-RAY LABORATORY AIDE                           47664.773077  52705.880385
# ...

# %%
data.groupby('JobTitle').mean()['BasePay']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18528\3409582655.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('JobTitle').mean()['BasePay']
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# ...

# %% [markdown]
# #### Find average basepay of Employee Having Job title ACCOUNTANT

# %%
data[data['JobTitle']=='ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# #### Find top 5 Most common Jobs

# %%
data['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
